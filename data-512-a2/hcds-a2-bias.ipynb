# %% [markdown]
# ## Data 512 A Assignment 2 - Bias in Data

# %% [markdown]
# ### Import necessary libraries

# %%
# %matplotlib inline
import requests
import json
import pandas as pd
import numpy as np

# %% [markdown]
# ### Define a utility function to pre-process the data and get prediction scores from the endpoint

# %%
def get_ores_data(revision_ids):
    """ Function to split revision IDs into smaller chunks before getting the quality scores using ORES API endpoint
    """
    # Define the endpoint
    endpoint = 'https://ores.wikimedia.org/v3/scores/enwiki/?models=wp10&revids={}'
    
    output_revision_ids = []
    predictions = []
    
    chunk_size = 100
    
    L = len(revision_ids)
    for  i in range(0, L, chunk_size):
        try:
            chunk_rev_id = revision_ids[i:i + chunk_size]
        except:
            chunk_rev_id = revision_ids[i:]
            
        formatted_url = endpoint.format("|".join(map(str, chunk_rev_id)))
        
        api_call = requests.get(formatted_url)
        response = api_call.json()
        prob_dict =  response['enwiki']['scores']
    
    
        for rev_id, result in prob_dict.items():
            output_revision_ids.append(rev_id)
            predictions.append(result['wp10'].get('score', {}).get('prediction', 'N/A'))
            
        print("processed rev IDs", i + chunk_size)
        
    return_df = pd.DataFrame({'revision_id' : output_revision_ids, 'predictions' : predictions})
    
    return return_df

# %% [markdown]
# ## Read the Wikipedia Dataset and the Population Data set into Dataframes

# %%
population = pd.read_csv('WPDS_2018_data.csv') 
wiki_data = pd.read_csv('page_data.csv')

# %%
# inspect population data
population.head()
# Out:
#   Geography Population mid-2018 (millions)
# 0    AFRICA                          1,284
# 1   Algeria                           42.7
# 2     Egypt                             97
# 3     Libya                            6.5
# 4   Morocco                           35.2

# %%
# inspect wiki data
wiki_data.head()
# Out:
#                                  page   country     rev_id
# 0  Template:ZambiaProvincialMinisters    Zambia  235107991
# 1                      Bir I of Kanem      Chad  355319463
# 2   Template:Zimbabwe-politician-stub  Zimbabwe  391862046
# 3     Template:Uganda-politician-stub    Uganda  391862070
# 4    Template:Namibia-politician-stub   Namibia  391862409

# %% [markdown]
# ## Join the population Dataframe with the wiki data

# %%
combined_df = pd.merge(population, wiki_data, how='inner', right_on='country', left_on='Geography')
combined_df.head()
# Out:
#   Geography Population mid-2018 (millions)                              page  \
# 0   Algeria                           42.7  Template:Algeria-politician-stub
# 1   Algeria                           42.7    Template:Algeria-diplomat-stub
# 2   Algeria                           42.7             Template:AlgerianPres
# 3   Algeria                           42.7                 Ali Fawzi Rebaine
# 4   Algeria                           42.7                       Ahmed Attaf
#
#    country     rev_id
# 0  Algeria  544347736
# 1  Algeria  567620838
# 2  Algeria  665948270
# 3  Algeria  686269631
# 4  Algeria  705910185

# %% [markdown]
# ## Use the ORES API to get the quality Scores for the Wikipedia Articles

# %%
quality_scores = get_ores_data(combined_df['rev_id'])
# Out:
# processed rev IDs 100
# processed rev IDs 200
# processed rev IDs 300
# processed rev IDs 400
# processed rev IDs 500
# processed rev IDs 600
# processed rev IDs 700
# processed rev IDs 800
# processed rev IDs 900
# processed rev IDs 1000
# processed rev IDs 1100
# processed rev IDs 1200
# processed rev IDs 1300
# processed rev IDs 1400
# processed rev IDs 1500
# processed rev IDs 1600
# processed rev IDs 1700
# processed rev IDs 1800
# processed rev IDs 1900
# processed rev IDs 2000
# processed rev IDs 2100
# processed rev IDs 2200
# processed rev IDs 2300
# processed rev IDs 2400
# processed rev IDs 2500
# processed rev IDs 2600
# processed rev IDs 2700
# processed rev IDs 2800
# processed rev IDs 2900
# processed rev IDs 3000
# processed rev IDs 3100
# processed rev IDs 3200
# processed rev IDs 3300
# processed rev IDs 3400
# processed rev IDs 3500
# processed rev IDs 3600
# processed rev IDs 3700
# processed rev IDs 3800
# processed rev IDs 3900
# processed rev IDs 4000
# processed rev IDs 4100
# processed rev IDs 4200
# processed rev IDs 4300
# processed rev IDs 4400
# processed rev IDs 4500
# processed rev IDs 4600
# processed rev IDs 4700
# processed rev IDs 4800
# processed rev IDs 4900
# processed rev IDs 5000
# processed rev IDs 5100
# processed rev IDs 5200
# processed rev IDs 5300
# processed rev IDs 5400
# processed rev IDs 5500
# processed rev IDs 5600
# processed rev IDs 5700
# processed rev IDs 5800
# processed rev IDs 5900
# processed rev IDs 6000
# processed rev IDs 6100
# processed rev IDs 6200
# processed rev IDs 6300
# processed rev IDs 6400
# processed rev IDs 6500
# processed rev IDs 6600
# processed rev IDs 6700
# processed rev IDs 6800
# processed rev IDs 6900
# processed rev IDs 7000
# processed rev IDs 7100
# processed rev IDs 7200
# processed rev IDs 7300
# processed rev IDs 7400
# processed rev IDs 7500
# processed rev IDs 7600
# processed rev IDs 7700
# processed rev IDs 7800
# processed rev IDs 7900
# processed rev IDs 8000
# processed rev IDs 8100
# processed rev IDs 8200
# processed rev IDs 8300
# processed rev IDs 8400
# processed rev IDs 8500
# processed rev IDs 8600
# processed rev IDs 8700
# processed rev IDs 8800
# processed rev IDs 8900
# processed rev IDs 9000
# processed rev IDs 9100
# processed rev IDs 9200
# processed rev IDs 9300
# processed rev IDs 9400
# processed rev IDs 9500
# processed rev IDs 9600
# processed rev IDs 9700
# processed rev IDs 9800
# processed rev IDs 9900
# processed rev IDs 10000
# processed rev IDs 10100
# processed rev IDs 10200
# processed rev IDs 10300
# processed rev IDs 10400
# processed rev IDs 10500
# processed rev IDs 10600
# processed rev IDs 10700
# processed rev IDs 10800
# processed rev IDs 10900
# processed rev IDs 11000
# processed rev IDs 11100
# processed rev IDs 11200
# processed rev IDs 11300
# processed rev IDs 11400
# processed rev IDs 11500
# processed rev IDs 11600
# processed rev IDs 11700
# processed rev IDs 11800
# processed rev IDs 11900
# processed rev IDs 12000
# processed rev IDs 12100
# processed rev IDs 12200
# processed rev IDs 12300
# processed rev IDs 12400
# processed rev IDs 12500
# processed rev IDs 12600
# processed rev IDs 12700
# processed rev IDs 12800
# processed rev IDs 12900
# processed rev IDs 13000
# processed rev IDs 13100
# processed rev IDs 13200
# processed rev IDs 13300
# processed rev IDs 13400
# processed rev IDs 13500
# processed rev IDs 13600
# processed rev IDs 13700
# processed rev IDs 13800
# processed rev IDs 13900
# processed rev IDs 14000
# processed rev IDs 14100
# processed rev IDs 14200
# processed rev IDs 14300
# processed rev IDs 14400
# processed rev IDs 14500
# processed rev IDs 14600
# processed rev IDs 14700
# processed rev IDs 14800
# processed rev IDs 14900
# processed rev IDs 15000
# processed rev IDs 15100
# processed rev IDs 15200
# processed rev IDs 15300
# processed rev IDs 15400
# processed rev IDs 15500
# processed rev IDs 15600
# processed rev IDs 15700
# processed rev IDs 15800
# processed rev IDs 15900
# processed rev IDs 16000
# processed rev IDs 16100
# processed rev IDs 16200
# processed rev IDs 16300
# processed rev IDs 16400
# processed rev IDs 16500
# processed rev IDs 16600
# processed rev IDs 16700
# processed rev IDs 16800
# processed rev IDs 16900
# processed rev IDs 17000
# processed rev IDs 17100
# processed rev IDs 17200
# processed rev IDs 17300
# processed rev IDs 17400
# processed rev IDs 17500
# processed rev IDs 17600
# processed rev IDs 17700
# processed rev IDs 17800
# processed rev IDs 17900
# processed rev IDs 18000
# processed rev IDs 18100
# processed rev IDs 18200
# processed rev IDs 18300
# processed rev IDs 18400
# processed rev IDs 18500
# processed rev IDs 18600
# processed rev IDs 18700
# processed rev IDs 18800
# processed rev IDs 18900
# processed rev IDs 19000
# processed rev IDs 19100
# processed rev IDs 19200
# processed rev IDs 19300
# processed rev IDs 19400
# processed rev IDs 19500
# processed rev IDs 19600
# processed rev IDs 19700
# processed rev IDs 19800
# processed rev IDs 19900
# processed rev IDs 20000
# processed rev IDs 20100
# processed rev IDs 20200
# processed rev IDs 20300
# processed rev IDs 20400
# processed rev IDs 20500
# processed rev IDs 20600
# processed rev IDs 20700
# processed rev IDs 20800
# processed rev IDs 20900
# processed rev IDs 21000
# processed rev IDs 21100
# processed rev IDs 21200
# processed rev IDs 21300
# processed rev IDs 21400
# processed rev IDs 21500
# processed rev IDs 21600
# processed rev IDs 21700
# processed rev IDs 21800
# processed rev IDs 21900
# processed rev IDs 22000
# processed rev IDs 22100
# processed rev IDs 22200
# processed rev IDs 22300
# processed rev IDs 22400
# processed rev IDs 22500
# processed rev IDs 22600
# processed rev IDs 22700
# processed rev IDs 22800
# processed rev IDs 22900
# processed rev IDs 23000
# processed rev IDs 23100
# processed rev IDs 23200
# processed rev IDs 23300
# processed rev IDs 23400
# processed rev IDs 23500
# processed rev IDs 23600
# processed rev IDs 23700
# processed rev IDs 23800
# processed rev IDs 23900
# processed rev IDs 24000
# processed rev IDs 24100
# processed rev IDs 24200
# processed rev IDs 24300
# processed rev IDs 24400
# processed rev IDs 24500
# processed rev IDs 24600
# processed rev IDs 24700
# processed rev IDs 24800
# processed rev IDs 24900
# processed rev IDs 25000
# processed rev IDs 25100
# processed rev IDs 25200
# processed rev IDs 25300
# processed rev IDs 25400
# processed rev IDs 25500
# processed rev IDs 25600
# processed rev IDs 25700
# processed rev IDs 25800
# processed rev IDs 25900
# processed rev IDs 26000
# processed rev IDs 26100
# processed rev IDs 26200
# processed rev IDs 26300
# processed rev IDs 26400
# processed rev IDs 26500
# processed rev IDs 26600
# processed rev IDs 26700
# processed rev IDs 26800
# processed rev IDs 26900
# processed rev IDs 27000
# processed rev IDs 27100
# processed rev IDs 27200
# processed rev IDs 27300
# processed rev IDs 27400
# processed rev IDs 27500
# processed rev IDs 27600
# processed rev IDs 27700
# processed rev IDs 27800
# processed rev IDs 27900
# processed rev IDs 28000
# processed rev IDs 28100
# processed rev IDs 28200
# processed rev IDs 28300
# processed rev IDs 28400
# processed rev IDs 28500
# processed rev IDs 28600
# processed rev IDs 28700
# processed rev IDs 28800
# processed rev IDs 28900
# processed rev IDs 29000
# processed rev IDs 29100
# processed rev IDs 29200
# processed rev IDs 29300
# processed rev IDs 29400
# processed rev IDs 29500
# processed rev IDs 29600
# processed rev IDs 29700
# processed rev IDs 29800
# processed rev IDs 29900
# processed rev IDs 30000
# processed rev IDs 30100
# processed rev IDs 30200
# processed rev IDs 30300
# processed rev IDs 30400
# processed rev IDs 30500
# processed rev IDs 30600
# processed rev IDs 30700
# processed rev IDs 30800
# processed rev IDs 30900
# processed rev IDs 31000
# processed rev IDs 31100
# processed rev IDs 31200
# processed rev IDs 31300
# processed rev IDs 31400
# processed rev IDs 31500
# processed rev IDs 31600
# processed rev IDs 31700
# processed rev IDs 31800
# processed rev IDs 31900
# processed rev IDs 32000
# processed rev IDs 32100
# processed rev IDs 32200
# processed rev IDs 32300
# processed rev IDs 32400
# processed rev IDs 32500
# processed rev IDs 32600
# processed rev IDs 32700
# processed rev IDs 32800
# processed rev IDs 32900
# processed rev IDs 33000
# processed rev IDs 33100
# processed rev IDs 33200
# processed rev IDs 33300
# processed rev IDs 33400
# processed rev IDs 33500
# processed rev IDs 33600
# processed rev IDs 33700
# processed rev IDs 33800
# processed rev IDs 33900
# processed rev IDs 34000
# processed rev IDs 34100
# processed rev IDs 34200
# processed rev IDs 34300
# processed rev IDs 34400
# processed rev IDs 34500
# processed rev IDs 34600
# processed rev IDs 34700
# processed rev IDs 34800
# processed rev IDs 34900
# processed rev IDs 35000
# processed rev IDs 35100
# processed rev IDs 35200
# processed rev IDs 35300
# processed rev IDs 35400
# processed rev IDs 35500
# processed rev IDs 35600
# processed rev IDs 35700
# processed rev IDs 35800
# processed rev IDs 35900
# processed rev IDs 36000
# processed rev IDs 36100
# processed rev IDs 36200
# processed rev IDs 36300
# processed rev IDs 36400
# processed rev IDs 36500
# processed rev IDs 36600
# processed rev IDs 36700
# processed rev IDs 36800
# processed rev IDs 36900
# processed rev IDs 37000
# processed rev IDs 37100
# processed rev IDs 37200
# processed rev IDs 37300
# processed rev IDs 37400
# processed rev IDs 37500
# processed rev IDs 37600
# processed rev IDs 37700
# processed rev IDs 37800
# processed rev IDs 37900
# processed rev IDs 38000
# processed rev IDs 38100
# processed rev IDs 38200
# processed rev IDs 38300
# processed rev IDs 38400
# processed rev IDs 38500
# processed rev IDs 38600
# processed rev IDs 38700
# processed rev IDs 38800
# processed rev IDs 38900
# processed rev IDs 39000
# processed rev IDs 39100
# processed rev IDs 39200
# processed rev IDs 39300
# processed rev IDs 39400
# processed rev IDs 39500
# processed rev IDs 39600
# processed rev IDs 39700
# processed rev IDs 39800
# processed rev IDs 39900
# processed rev IDs 40000
# processed rev IDs 40100
# processed rev IDs 40200
# processed rev IDs 40300
# processed rev IDs 40400
# processed rev IDs 40500
# processed rev IDs 40600
# processed rev IDs 40700
# processed rev IDs 40800
# processed rev IDs 40900
# processed rev IDs 41000
# processed rev IDs 41100
# processed rev IDs 41200
# processed rev IDs 41300
# processed rev IDs 41400
# processed rev IDs 41500
# processed rev IDs 41600
# processed rev IDs 41700
# processed rev IDs 41800
# processed rev IDs 41900
# processed rev IDs 42000
# processed rev IDs 42100
# processed rev IDs 42200
# processed rev IDs 42300
# processed rev IDs 42400
# processed rev IDs 42500
# processed rev IDs 42600
# processed rev IDs 42700
# processed rev IDs 42800
# processed rev IDs 42900
# processed rev IDs 43000
# processed rev IDs 43100
# processed rev IDs 43200
# processed rev IDs 43300
# processed rev IDs 43400
# processed rev IDs 43500
# processed rev IDs 43600
# processed rev IDs 43700
# processed rev IDs 43800
# processed rev IDs 43900
# processed rev IDs 44000
# processed rev IDs 44100
# processed rev IDs 44200
# processed rev IDs 44300
# processed rev IDs 44400
# processed rev IDs 44500
# processed rev IDs 44600
# processed rev IDs 44700
# processed rev IDs 44800
# processed rev IDs 44900
# processed rev IDs 45000
# processed rev IDs 45100

# %%
# Inspect the quality score Data Frame
quality_scores.head()
# Out:
#   revision_id predictions
# 0   544347736        Stub
# 1   567620838        Stub
# 2   665948270        Stub
# 3   686269631        Stub
# 4   705910185        Stub

# %%
# Convert rev_id column in combined_df to type int64
combined_df['rev_id'] = combined_df['rev_id'].astype(int)

# %%
# Convert revision_id column in the quality scores df to type int64
quality_scores['revision_id'] = quality_scores['revision_id'].astype(int)

# %% [markdown]
# ## Join the quality scores Data Frame with the combined Data Frame

# %%
combined_quality_df = pd.merge(combined_df, quality_scores, how='inner', left_on='rev_id', right_on='revision_id')

# %%
## Inspect combined_quality_df
combined_quality_df.head()
# Out:
#   Geography Population mid-2018 (millions)                              page  \
# 0   Algeria                           42.7  Template:Algeria-politician-stub
# 1   Algeria                           42.7    Template:Algeria-diplomat-stub
# 2   Algeria                           42.7             Template:AlgerianPres
# 3   Algeria                           42.7                 Ali Fawzi Rebaine
# 4   Algeria                           42.7                       Ahmed Attaf
#
#    country     rev_id  revision_id predictions
# 0  Algeria  544347736    544347736        Stub
# 1  Algeria  567620838    567620838        Stub
# 2  Algeria  665948270    665948270        Stub
# 3  Algeria  686269631    686269631        Stub
# 4  Algeria  705910185    705910185        Stub

# %% [markdown]
# ## Persist the results in a CSV file

# %%
persist_df = pd.DataFrame()

persist_df['country'] = combined_quality_df['country']
persist_df['article_name'] = combined_quality_df['page']
persist_df['revision_id'] = combined_quality_df['rev_id']
persist_df['article_quality'] = combined_quality_df['predictions']
persist_df['population'] = combined_quality_df['Population mid-2018 (millions)']

# Inspect persist_df before writing to disk
persist_df.head()
# Out:
#    country                      article_name  revision_id article_quality  \
# 0  Algeria  Template:Algeria-politician-stub    544347736            Stub
# 1  Algeria    Template:Algeria-diplomat-stub    567620838            Stub
# 2  Algeria             Template:AlgerianPres    665948270            Stub
# 3  Algeria                 Ali Fawzi Rebaine    686269631            Stub
# 4  Algeria                       Ahmed Attaf    705910185            Stub
#
#   population
# 0       42.7
# 1       42.7
# 2       42.7
# 3       42.7
# 4       42.7

# %%
# Write the persist_df to a csv file
persist_df.to_csv('final_data.csv')

# %% [markdown]
# ## Read the Persisted CSV file for Analysis

# %%
persist_df = pd.read_csv('final_data.csv')

# %%
# Convert population to a floating point value
persist_df['population'] = persist_df['population'].apply(lambda x : float(x.replace(',', '')))

# %%
# Compute the Aggregated columns
table_1 = persist_df.groupby('country').agg({'revision_id' : lambda x : len(x), 'population' : np.mean})

# %%
# Compute the proportion of articles wrt the population of the country
table_1['proportion_%'] = table_1.apply(lambda x : x['revision_id'] / x['population'] / (10 ** 6) * 100, axis='columns')
table_1.rename(columns={'revision_id' : 'Article Counts', 'population' : 'Population in Millions'}, inplace=True)

# %% [markdown]
# ## 10 highest-ranked countries in terms of number of politician articles as a proportion of country population

# %%
table_1_top_10 = table_1.sort_values('proportion_%', ascending=False)[:10]
table_1_top_10.head(10)
# Out:
#                                 Article Counts  Population in Millions  \
# country
# Tuvalu                                      55                    0.01
# Nauru                                       53                    0.01
# San Marino                                  82                    0.03
# Monaco                                      40                    0.04
# Liechtenstein                               29                    0.04
# Tonga                                       63                    0.10
# Marshall Islands                            37                    0.06
# Iceland                                    206                    0.40
# Andorra                                     34                    0.08
# Federated States of Micronesia              38                    0.10
#
#                                 proportion_%
# country
# Tuvalu                              0.550000
# Nauru                               0.530000
# San Marino                          0.273333
# Monaco                              0.100000
# Liechtenstein                       0.072500
# Tonga                               0.063000
# Marshall Islands                    0.061667
# Iceland                             0.051500
# Andorra                             0.042500
# Federated States of Micronesia      0.038000

# %% [markdown]
# ### Reflection
# * Most of the countries in this list tend to have relatively low population and as a result tend to have higher proportion of articles wrt the population.
# * This analysis can be biased, because of the fact that certain countries with low population may have a high proportion of people who are illiterate and as a result have very few articles written in general.
# * It is also possible that the proportion is abnormally high for a country with low population because of a select few people writing a lot of political articles.

# %% [markdown]
# ## 10 lowest-ranked countries in terms of number of politician articles as a proportion of country population

# %%
table_1_bottom_10 = table_1.sort_values('proportion_%', ascending=True)[:10]
table_1_bottom_10.head(10)
# Out:
#               Article Counts  Population in Millions  proportion_%
# country
# India                    990                  1371.3      0.000072
# Indonesia                215                   265.2      0.000081
# China                   1138                  1393.8      0.000082
# Uzbekistan                29                    32.9      0.000088
# Ethiopia                 105                   107.5      0.000098
# Zambia                    26                    17.7      0.000147
# Korea, North              39                    25.6      0.000152
# Thailand                 112                    66.2      0.000169
# Bangladesh               324                   166.4      0.000195
# Mozambique                60                    30.5      0.000197

# %% [markdown]
# ### Reflection
# * This analysis can also be biased because of the fact that some countries like India and China have a relatively high population and as a result have lower proportion value
# * Another source of bias could be the variablity of literacy rate among countries

# %% [markdown]
# ## Consider High quality articles only

# %%
persist_df['high_quality'] = persist_df['article_quality'].apply(lambda x : 1 if x in ('GA', 'FA') else 0)
persist_df.head()
# Out:
#    Unnamed: 0  country                      article_name  revision_id  \
# 0           0  Algeria  Template:Algeria-politician-stub    544347736
# 1           1  Algeria    Template:Algeria-diplomat-stub    567620838
# 2           2  Algeria             Template:AlgerianPres    665948270
# 3           3  Algeria                 Ali Fawzi Rebaine    686269631
# 4           4  Algeria                       Ahmed Attaf    705910185
#
#   article_quality  population  high_quality
# 0            Stub        42.7             0
# 1            Stub        42.7             0
# 2            Stub        42.7             0
# 3            Stub        42.7             0
# 4            Stub        42.7             0

# %%
# Compute aggregated columns ie. article counts and population

table_2 = persist_df.groupby('country').agg({'revision_id' : lambda x : len(x), 'high_quality' : np.sum})
table_2['proportion_%'] = table_2.apply(lambda x : x['high_quality'] / x['revision_id'] / 10000, 
                                        axis='columns')
table_2.rename(columns={'revision_id' : 'Article Counts', 'population' : 'Population in Millions'}, inplace=True)

# %% [markdown]
# ### 10 highest-ranked countries in terms of number of GA and FA-quality articles as a proportion of all articles about politicians from that country

# %%
table_2_top_10 = table_2.sort_values('proportion_%', ascending=False)[:10]
table_2_top_10.head(10)
# Out:
#                           Article Counts  high_quality  proportion_%
# country
# Korea, North                          39             7      0.000018
# Saudi Arabia                         119            16      0.000013
# Central African Republic              68             8      0.000012
# Romania                              348            40      0.000011
# Mauritania                            52             5      0.000010
# Bhutan                                33             3      0.000009
# Tuvalu                                55             5      0.000009
# Dominica                              12             1      0.000008
# United States                       1098            82      0.000007
# Benin                                 94             7      0.000007

# %% [markdown]
# ### Reflection
# * This analysis could be biased because of the fact that certain countries have higher degree of freedom of speech than others
# * If the freedom of speech is restricted in certain countries, fewer people are likely to contribute articles and those that do contribute articles tend to be professional writers that produce higher quality articles

# %% [markdown]
# ### 10 lowest-ranked countries in terms of number of GA and FA-quality articles as a proportion of all articles about politicians from that country

# %%
# List all the countries with zero high quality articles and sort them in the descending order of the number of articles
table_2_bottom_10 = table_2.sort_values('proportion_%', ascending=True)
table_2_bottom_10 = table_2_bottom_10[table_2_bottom_10['high_quality'] < 0.000001].sort_values('Article Counts', ascending=False)[:10]
table_2_bottom_10.head(10)
# Out:
#              Article Counts  high_quality  proportion_%
# country
# Finland                 572             0           0.0
# Belgium                 523             0           0.0
# Moldova                 426             0           0.0
# Switzerland             407             0           0.0
# Nepal                   363             0           0.0
# Uganda                  188             0           0.0
# Costa Rica              150             0           0.0
# Tunisia                 140             0           0.0
# Slovakia                119             0           0.0
# Angola                  110             0           0.0

# %% [markdown]
# ### Reflection
# * Here we see a mix of developed and underdeveloped countries in the list with no high quality articles
# * It is possible that people in certain developed and underdeveloped countries don't contribute a lot of political articles
# * It's also possible that the data in not comprehensive
# * Any conclusions we draw from this analysis will definitely be full of Bias.
